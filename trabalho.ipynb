# %%
pip install notebook
# Out:
# ...
#      ---------------------------------------- 5.5/5.5 MB 2.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 915.3/915.3 kB 2.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 393.1/393.1 kB 2.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 59.8/59.8 kB 799.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 17.2/17.2 MB 1.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 125.8/125.8 kB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 134.9/134.9 kB 1.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 261.9/261.9 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 79.8/79.8 kB 2.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 64.5/64.5 kB 861.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.1/2.1 MB 2.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 82.6/82.6 kB 770.0 kB/s eta 0:00:00
# ...

# %%
pip install jupyterlab
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 10.0/10.0 MB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 12.6/12.6 MB 1.5 MB/s eta 0:00:00
# ...
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\orion\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pd.read_csv("anime.csv")
# Out:
#       anime_id                                              title  score  \
# 0        28977                                           Gintama°   9.05
# 1        57555                       Chainsaw Man Movie: Reze-hen   9.18
# 2        11061                             Hunter x Hunter (2011)   9.03
# 3        52991                                  Sousou no Frieren   9.29
# 4         9969                                           Gintama'   9.02
# ...        ...                                                ...    ...
# 9995      1351                                          Angel Cop   6.05
# 9996     33339                          Zhongguo Jingqi Xiansheng   6.05
# 9997      2840                              Youkoso Lodoss-tou e!   6.05
# 9998     33764                                 Ying Xiong Bie Nao   6.05
# 9999     49700  Arifureta Shokugyou de Sekai Saikyou Picture D...   6.05
#
#       rank  popularity  members  \
# 0        8         347   680037
# ...
